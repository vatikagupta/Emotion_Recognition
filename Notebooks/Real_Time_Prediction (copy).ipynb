# %%
import  cv2
import numpy as np
import time
from keras.models import load_model
from keras.applications import VGG16
import matplotlib.pyplot as plt
from PIL import Image

# %%
EMOTION_DICT = {1:"ANGRY", 2:"DISGUST", 3:"FEAR", 4:"HAPPY", 5:"NEUTRAL", 6:"SAD", 7:"SURPRISE"}
model_VGG = VGG16(weights='imagenet', include_top=False)
model_top = load_model("../Data/Model_Save/model.h5")

# %%
def return_prediction(path):
    #converting image to gray scale and save it
    img = cv2.imread(path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(path, gray)
    img_height = 350
    img_width = 350
    
    #detect face in image, crop it then resize it then save it
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') 
    img = cv2.imread(path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        face_clip = img[y:y+h, x:x+w]
        cv2.imwrite(path, cv2.resize(face_clip, (350, 350)))
    
    #read the processed image then make prediction and display the result
    read_image = cv2.imread(path)
    read_image_final = read_image/255.0  #normalizing the image
    #read_image = read_image.reshape(1, read_image.shape[0], read_image.shape[1], read_image.shape[2])
    read_image_final = cv2.resize(read_image, (img_height, img_width))
    read_image_final = np.expand_dims(read_image_final, axis = 0)
    #read_image_final = image.astype('uint8')
    VGG_Pred = model_VGG.predict(read_image_final)
    VGG_Pred = VGG_Pred.reshape(1, VGG_Pred.shape[1]*VGG_Pred.shape[2]*VGG_Pred.shape[3])
    top_pred = model_top.predict(VGG_Pred)
    emotion_label = top_pred[0].argmax() + 1
    print("Predic run")
    return EMOTION_DICT[emotion_label]

# %%
def rerun(text, cap):
    while(True):
        ret, img = cap.read()
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        font = cv2.FONT_HERSHEY_SIMPLEX
        #cv2.putText(img, "Last Emotion was "+str(text), (95,30), font, 1.0, (255, 0, 0), 2, cv2.LINE_AA)
        
        cv2.putText(img, "Press SPACE: FOR EMOTION", (5,470), font, 0.7, (255, 0, 0), 2, cv2.LINE_AA)
    
        #cv2.putText(img, "Hold Q: To Quit", (460,470), font, 0.7, (255, 0, 0), 2, cv2.LINE_AA)
    
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for x,y,w,h in faces:
            cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)
        cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("Image", 1200, 750)
        cv2.imshow("Image", img)
        #if cv2.waitKey(1) == ord(' '):
        cv2.imwrite("test.jpg", img)
        #time.sleep(2)
        cv2.putText(img, " Emotion is "+str(text), (95,30), font, 1.0, (255, 0, 0), 2, cv2.LINE_AA)
        text = return_prediction("test.jpg")
        print("rerun")
        print(text)
        if cv2.waitKey(1) == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            break
        time.sleep(1)
        rerun(text, cap)
            #break

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') 

cap = cv2.VideoCapture(0)

def first_run(text, cap):
    while(True):
        ret, img = cap.read()
#         print(type(img))
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
        font = cv2.FONT_HERSHEY_SIMPLEX
        #cv2.putText(img, "Last Emotion was "+str(text), (95,30), font, 1.0, (255, 0, 0), 2, cv2.LINE_AA)
        
        cv2.putText(img, "Press SPACE: FOR EMOTION", (5,470), font, 0.7, (255, 0, 0), 2, cv2.LINE_AA)
    
        #cv2.putText(img, "Hold Q: To Quit", (460,470), font, 0.7, (255, 0, 0), 2, cv2.LINE_AA)
    
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for x,y,w,h in faces:
            cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)
        cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("Image", 1200, 750)
        cv2.imshow("Image", img)
        cv2.imwrite("test.jpg", img)        
        #if cv2.waitKey(1) == ord(' '):
        cv2.putText(img, " Emotion is "+str(text), (95,30), font, 1.0, (255, 255, 0), 2, cv2.LINE_AA)
        text = return_prediction("test.jpg")
        print("first run")
        print(text)
        if cv2.waitKey(1) == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            break
        time.sleep(1)
        rerun(text, cap)
            #break

# %%
first_run("None", cap)
# Out:
# Predic run
# first run
# DISGUST
# Predic run
# rerun
# DISGUST
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# HAPPY
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# HAPPY
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# NEUTRAL
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# ANGRY
# Predic run
# rerun
# ANGRY
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-142-b4d8a839524a> in <module>
# ----> 1 first_run("None", cap)
#
# <ipython-input-141-0ff5d435a480> in first_run(text, cap)
#      33             break
#      34         time.sleep(1)
# ---> 35         rerun(text, cap)
#      36             #break
#      37
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#      28             break
#      29         time.sleep(1)
# ---> 30         rerun(text, cap)
#      31             #break
#      32
#
# <ipython-input-140-13c91f44d14e> in rerun(text, cap)
#       2     while(True):
#       3         ret, img = cap.read()
# ----> 4         gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       5         font = cv2.FONT_HERSHEY_SIMPLEX
#       6         #cv2.putText(img, "Last Emotion was "+str(text), (95,30), font, 1.0, (255, 0, 0), 2, cv2.LINE_AA)
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
Image.open("../Notebooks/test.jpg")
